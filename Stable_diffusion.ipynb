# %% [markdown]
# <a href="https://colab.research.google.com/github/CrimsonRed89/AI-Image-Generator-Stable-Diffusion/blob/main/Stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers["torch"]
from diffusers import StableDiffusionPipeline

# %%
import torch
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16)

# %%
pipe.to("cuda")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
input_prompt = str(input())
prompt = input_prompt

image  = pipe(prompt).images[0]

plt.imshow(image)
plt.axis('off')
plt.show(image)

image.save(f"{prompt}.png")
# Out:
# a white heavenly horse
#   0%|          | 0/50 [00:00<?, ?it/s]
